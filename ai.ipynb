# %%
import os, ssl, smtplib
from email.message import EmailMessage
from dotenv import load_dotenv

load_dotenv()

SMTP_HOST = os.getenv("SMTP_HOST")
SMTP_PORT = int(os.getenv("SMTP_PORT", "465"))
SMTP_USER = os.getenv("SMTP_USER")
SMTP_PASSWORD = os.getenv("SMTP_PASSWORD")

msg = EmailMessage()
msg["From"] = SMTP_USER
msg["To"] = os.getenv("FORWARD_TO_EMAIL")   # send test to Basim
msg["Subject"] = "SMTP Test from Python Agent"
msg.set_content("Hello! This is a direct SMTP test from Python.")

print("Connecting to SMTP...")
ctx = ssl.create_default_context()
with smtplib.SMTP_SSL(SMTP_HOST, SMTP_PORT, context=ctx) as server:
    server.login(SMTP_USER, SMTP_PASSWORD)
    server.send_message(msg)

print("✅ Sent test mail")
# Out:
# Connecting to SMTP...
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# Cell In[1], line 20
#      18 print("Connecting to SMTP...")
#      19 ctx = ssl.create_default_context()
# ---> 20 with smtplib.SMTP_SSL(SMTP_HOST, SMTP_PORT, context=ctx) as server:
#      21     server.login(SMTP_USER, SMTP_PASSWORD)
#      22     server.send_message(msg)
#
# File c:\ProgramData\anaconda3\envs\ml\Lib\smtplib.py:1050, in SMTP_SSL.__init__(self, host, port, local_hostname, keyfile, certfile, timeout, source_address, context)
#    1047     context = ssl._create_stdlib_context(certfile=certfile,
#    1048                                          keyfile=keyfile)
#    1049 self.context = context
# -> 1050 SMTP.__init__(self, host, port, local_hostname, timeout,
#    1051               source_address)
#
# File c:\ProgramData\anaconda3\envs\ml\Lib\smtplib.py:255, in SMTP.__init__(self, host, port, local_hostname, timeout, source_address)
#     252 self._auth_challenge_count = 0
#     254 if host:
# --> 255     (code, msg) = self.connect(host, port)
#     256     if code != 220:
#     257         self.close()
#
# File c:\ProgramData\anaconda3\envs\ml\Lib\smtplib.py:341, in SMTP.connect(self, host, port, source_address)
#     339     port = self.default_port
#     340 sys.audit("smtplib.connect", self, host, port)
# --> 341 self.sock = self._get_socket(host, port, self.timeout)
#     342 self.file = None
#     343 (code, msg) = self.getreply()
#
# File c:\ProgramData\anaconda3\envs\ml\Lib\smtplib.py:1056, in SMTP_SSL._get_socket(self, host, port, timeout)
#    1054 if self.debuglevel > 0:
#    1055     self._print_debug('connect:', (host, port))
# -> 1056 new_socket = super()._get_socket(host, port, timeout)
#    1057 new_socket = self.context.wrap_socket(new_socket,
#    1058                                       server_hostname=self._host)
#    1059 return new_socket
#
# File c:\ProgramData\anaconda3\envs\ml\Lib\smtplib.py:312, in SMTP._get_socket(self, host, port, timeout)
#     310 if self.debuglevel > 0:
#     311     self._print_debug('connect: to', (host, port), self.source_address)
# --> 312 return socket.create_connection((host, port), timeout,
#     313                                 self.source_address)
#
# File c:\ProgramData\anaconda3\envs\ml\Lib\socket.py:839, in create_connection(address, timeout, source_address, all_errors)
#     837 host, port = address
#     838 exceptions = []
# --> 839 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     840     af, socktype, proto, canonname, sa = res
#     841     sock = None
#
# File c:\ProgramData\anaconda3\envs\ml\Lib\socket.py:974, in getaddrinfo(host, port, family, type, proto, flags)
#     971 # We override this function since we want to translate the numeric family
#     972 # and socket type values to enum constants.
#     973 addrlist = []
# --> 974 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     975     af, socktype, proto, canonname, sa = res
#     976     addrlist.append((_intenum_converter(af, AddressFamily),
#     977                      _intenum_converter(socktype, SocketKind),
#     978                      proto, canonname, sa))
#
# gaierror: [Errno 11001] getaddrinfo failed
